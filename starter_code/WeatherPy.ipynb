# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
#!pip install citipy
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 642

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"

#Define empty lists to store values
cloudiness = []
country = []
date = []
max_temp = []
humidity = []
lat = []
lng = []
wind_speed = []
city_name = []

#Looping through cities to make api calls using city as query
i = 1
for city in cities:
    city=city
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    
#Extracting data. Missing data is handled by try and except  
    try:
        
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        max_temp.append(response["main"]['temp_max'])
        humidity.append(response["main"]['humidity'])
        lat.append(response["coord"]["lat"])  
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_name.append(response["name"])
        print(f"Processing record {i}|{city}")
        i+=1
    except (KeyError):
        print("City not found. skipping.")
# Out:
# Processing record 1|atuona
# Processing record 2|joshimath
# Processing record 3|lavrentiya
# Processing record 4|busselton
# Processing record 5|erenhot
# Processing record 6|tasiilaq
# Processing record 7|hilo
# City not found. skipping.
# Processing record 8|butaritari
# Processing record 9|ushuaia
# Processing record 10|punta arenas
# Processing record 11|san patricio
# Processing record 12|hobart
# Processing record 13|praxedis guerrero
# Processing record 14|airai
# Processing record 15|gairo
# Processing record 16|rikitea
# Processing record 17|albany
# Processing record 18|paamiut
# Processing record 19|port alfred
# Processing record 20|kudahuvadhoo
# Processing record 21|marawi
# Processing record 22|korem
# Processing record 23|qaanaaq
# Processing record 24|comodoro rivadavia
# Processing record 25|cochrane
# Processing record 26|hermanus
# Processing record 27|itarema
# Processing record 28|bredasdorp
# Processing record 29|sao miguel do araguaia
# Processing record 30|kudat
# City not found. skipping.
# Processing record 31|xichang
# Processing record 32|hasaki
# Processing record 33|marzuq
# Processing record 34|konevo
# Processing record 35|khatanga
# Processing record 36|tupelo
# Processing record 37|cedar city
# City not found. skipping.
# Processing record 38|udachnyy
# Processing record 39|cape town
# Processing record 40|teya
# City not found. skipping.
# Processing record 41|provideniya
# Processing record 42|esperance
# Processing record 43|moose factory
# Processing record 44|vaini
# Processing record 45|maroantsetra
# Processing record 46|axim
# Processing record 47|new norfolk
# Processing record 48|abu samrah
# Processing record 49|bengkulu
# Processing record 50|east london
# Processing record 51|galveston
# Processing record 52|arraial do cabo
# Processing record 53|vila franca do campo
# Processing record 54|olinda
# Processing record 55|tanete
# Processing record 56|russell
# Processing record 57|mar del plata
# Processing record 58|barrow
# Processing record 59|victoria
# Processing record 60|alofi
# Processing record 61|mahebourg
# Processing record 62|norman wells
# Processing record 63|chuy
# Processing record 64|ngawi
# Processing record 65|bluff
# Processing record 66|tauramena
# Processing record 67|longyearbyen
# Processing record 68|cayenne
# Processing record 69|carutapera
# Processing record 70|mataura
# Processing record 71|severo-kurilsk
# Processing record 72|touros
# Processing record 73|mayo
# Processing record 74|buala
# Processing record 75|enkoping
# Processing record 76|georgetown
# Processing record 77|thinadhoo
# Processing record 78|hudson bay
# Processing record 79|savannah bight
# Processing record 80|kuyanovo
# Processing record 81|ahuimanu
# Processing record 82|sinnamary
# City not found. skipping.
# Processing record 83|muskogee
# City not found. skipping.
# City not found. skipping.
# Processing record 84|hwange
# City not found. skipping.
# Processing record 85|sitka
# Processing record 86|izumo
# Processing record 87|chokurdakh
# Processing record 88|cam ranh
# Processing record 89|phalodi
# City not found. skipping.
# Processing record 90|coahuayana
# Processing record 91|ambon
# Processing record 92|aleksandrovka
# Processing record 93|avarua
# Processing record 94|bonthe
# Processing record 95|emerald
# City not found. skipping.
# Processing record 96|sumbe
# Processing record 97|luderitz
# Processing record 98|hami
# Processing record 99|tiksi
# Processing record 100|kishtwar
# Processing record 101|saskylakh
# City not found. skipping.
# Processing record 102|komsomolskiy
# Processing record 103|kavaratti
# Processing record 104|jamestown
# Processing record 105|labuhan
# Processing record 106|dudinka
# Processing record 107|yumen
# Processing record 108|port macquarie
# Processing record 109|beringovskiy
# Processing record 110|karlshamn
# Processing record 111|adrar
# Processing record 112|zaysan
# Processing record 113|samarai
# Processing record 114|yellowknife
# Processing record 115|buraydah
# Processing record 116|gazanjyk
# Processing record 117|san francisco
# Processing record 118|dawlatabad
# City not found. skipping.
# Processing record 119|islamkot
# Processing record 120|kapaa
# Processing record 121|alcudia
# Processing record 122|leeton
# Processing record 123|ponta do sol
# Processing record 124|garanhuns
# Processing record 125|eldorado
# Processing record 126|manzhouli
# Processing record 127|nanakuli
# Processing record 128|katsuura
# City not found. skipping.
# Processing record 129|sao filipe
# Processing record 130|saint-philippe
# Processing record 131|charagua
# Processing record 132|kodiak
# City not found. skipping.
# Processing record 133|lerum
# Processing record 134|bam
# Processing record 135|vila
# Processing record 136|pauini
# City not found. skipping.
# Processing record 137|talara
# City not found. skipping.
# Processing record 138|hvide sande
# Processing record 139|batticaloa
# Processing record 140|salinopolis
# Processing record 141|saratoga springs
# Processing record 142|salalah
# Processing record 143|alenquer
# Processing record 144|kushmurun
# Processing record 145|yakeshi
# Processing record 146|bubaque
# Processing record 147|camacha
# Processing record 148|edd
# Processing record 149|port elizabeth
# Processing record 150|parrita
# Processing record 151|chara
# Processing record 152|kruisfontein
# Processing record 153|laguna
# Processing record 154|samfya
# Processing record 155|roald
# Processing record 156|codrington
# Processing record 157|guerrero negro
# Processing record 158|vestmannaeyjar
# Processing record 159|tuktoyaktuk
# Processing record 160|cidreira
# Processing record 161|severnoye
# Processing record 162|trairi
# Processing record 163|klaksvik
# Processing record 164|fare
# Processing record 165|micheweni
# Processing record 166|eydhafushi
# Processing record 167|doha
# Processing record 168|novobiryusinskiy
# Processing record 169|sabha
# Processing record 170|isangel
# City not found. skipping.
# Processing record 171|chumikan
# Processing record 172|tocopilla
# Processing record 173|ugoofaaru
# Processing record 174|saldanha
# Processing record 175|lamu
# Processing record 176|saint marys
# Processing record 177|nabire
# City not found. skipping.
# Processing record 178|ojinaga
# Processing record 179|vanino
# Processing record 180|uruzgan
# Processing record 181|ilulissat
# Processing record 182|jieshi
# Processing record 183|puerto ayora
# Processing record 184|bambanglipuro
# Processing record 185|erzin
# Processing record 186|tabou
# City not found. skipping.
# Processing record 187|rawson
# Processing record 188|muskegon
# Processing record 189|tuatapere
# Processing record 190|brooks
# Processing record 191|zhigansk
# Processing record 192|rajbiraj
# Processing record 193|avera
# Processing record 194|north bend
# City not found. skipping.
# Processing record 195|tiznit
# Processing record 196|naze
# City not found. skipping.
# Processing record 197|tautira
# Processing record 198|neuquen
# Processing record 199|lebowakgomo
# Processing record 200|kalemie
# Processing record 201|lebu
# Processing record 202|atar
# Processing record 203|bambous virieux
# Processing record 204|matara
# Processing record 205|tarakan
# Processing record 206|dikson
# Processing record 207|boralday
# Processing record 208|anloga
# City not found. skipping.
# Processing record 209|gamba
# Processing record 210|faanui
# Processing record 211|hearst
# Processing record 212|barcelona
# Processing record 213|aitape
# Processing record 214|ribeira grande
# Processing record 215|hithadhoo
# Processing record 216|bud
# Processing record 217|hamilton
# Processing record 218|nikolskoye
# Processing record 219|necochea
# Processing record 220|pangnirtung
# Processing record 221|puerto escondido
# Processing record 222|hofn
# Processing record 223|liling
# Processing record 224|egvekinot
# Processing record 225|west plains
# Processing record 226|thunder bay
# Processing record 227|gat
# Processing record 228|krasnotorka
# Processing record 229|aksu
# Processing record 230|pevek
# Processing record 231|svetlogorsk
# Processing record 232|sangar
# Processing record 233|bethel
# Processing record 234|nantucket
# Processing record 235|dauriya
# Processing record 236|castro
# Processing record 237|leshukonskoye
# Processing record 238|praia
# Processing record 239|mombetsu
# Processing record 240|save
# Processing record 241|vardo
# Processing record 242|soavinandriana
# Processing record 243|jatiroto
# Processing record 244|sandpoint
# Processing record 245|konya
# Processing record 246|yangambi
# Processing record 247|primo tapia
# Processing record 248|tongchuan
# City not found. skipping.
# Processing record 249|takoradi
# Processing record 250|ankang
# Processing record 251|quatre cocos
# Processing record 252|naushki
# Processing record 253|batemans bay
# Processing record 254|thompson
# Processing record 255|zabol
# Processing record 256|souillac
# Processing record 257|barcelos
# Processing record 258|george
# Processing record 259|broken hill
# Processing record 260|lorengau
# Processing record 261|berlevag
# Processing record 262|kieta
# Processing record 263|banepa
# Processing record 264|fenoarivo atsinanana
# Processing record 265|nefteyugansk
# Processing record 266|kansanshi
# Processing record 267|saint paul
# Processing record 268|skjervoy
# Processing record 269|sorong
# Processing record 270|okhotsk
# Processing record 271|saint george
# Processing record 272|okakarara
# Processing record 273|yatou
# Processing record 274|yazd
# City not found. skipping.
# Processing record 275|torbay
# Processing record 276|saint-augustin
# Processing record 277|lata
# Processing record 278|upernavik
# Processing record 279|port hedland
# Processing record 280|panaba
# Processing record 281|mount gambier
# Processing record 282|matagami
# Processing record 283|awjilah
# Processing record 284|plastun
# Processing record 285|dedovichi
# Processing record 286|bakchar
# Processing record 287|maku
# Processing record 288|mgachi
# Processing record 289|ranfurly
# Processing record 290|dhidhdhoo
# Processing record 291|pampierstad
# Processing record 292|solnechnyy
# Processing record 293|carnarvon
# Processing record 294|sorland
# Processing record 295|san giovanni rotondo
# Processing record 296|stefanesti
# Processing record 297|olga
# Processing record 298|mikhaylovka
# Processing record 299|buchanan
# Processing record 300|geraldton
# Processing record 301|annau
# Processing record 302|pacific grove
# Processing record 303|mandawar
# Processing record 304|copperas cove
# Processing record 305|baiyin
# Processing record 306|tabory
# Processing record 307|fortuna
# Processing record 308|kwinana
# Processing record 309|nuuk
# City not found. skipping.
# Processing record 310|ambanja
# Processing record 311|laukaa
# Processing record 312|poum
# Processing record 313|narsaq
# Processing record 314|royan
# Processing record 315|ukiah
# Processing record 316|ixtapa
# Processing record 317|prainha
# Processing record 318|villa maria
# Processing record 319|vestmanna
# Processing record 320|moerai
# Processing record 321|fergus falls
# Processing record 322|boyolangu
# Processing record 323|kupang
# Processing record 324|iqaluit
# Processing record 325|kaitangata
# Processing record 326|roma
# Processing record 327|aracati
# Processing record 328|punta alta
# Processing record 329|tomatlan
# Processing record 330|albanel
# Processing record 331|boshnyakovo
# Processing record 332|jalu
# Processing record 333|cherskiy
# Processing record 334|mahibadhoo
# Processing record 335|ratnagiri
# City not found. skipping.
# Processing record 336|cairns
# Processing record 337|cooma
# Processing record 338|kikwit
# Processing record 339|nha trang
# Processing record 340|ayodhya
# Processing record 341|kant
# Processing record 342|brae
# Processing record 343|borba
# Processing record 344|ilebo
# City not found. skipping.
# Processing record 345|westport
# Processing record 346|baturaja
# Processing record 347|tigil
# City not found. skipping.
# Processing record 348|bordighera
# Processing record 349|kahului
# Processing record 350|cuiaba
# Processing record 351|santa isabel do rio negro
# City not found. skipping.
# City not found. skipping.
# Processing record 352|shulan
# Processing record 353|verkhoyansk
# Processing record 354|san policarpo
# Processing record 355|mangaldai
# Processing record 356|petropavlovsk-kamchatskiy
# Processing record 357|calatayud
# Processing record 358|trat
# Processing record 359|goderich
# Processing record 360|grindavik
# Processing record 361|san vicente
# Processing record 362|nador
# Processing record 363|suntar
# Processing record 364|finschhafen
# Processing record 365|hobyo
# Processing record 366|knysna
# Processing record 367|do gonbadan
# Processing record 368|bonavista
# Processing record 369|santa rosa
# Processing record 370|carthage
# Processing record 371|misratah
# City not found. skipping.
# Processing record 372|tutoia
# Processing record 373|verkh-usugli
# City not found. skipping.
# Processing record 374|montepuez
# Processing record 375|coyoles
# Processing record 376|granadilla de abona
# Processing record 377|lagoa
# Processing record 378|jiuquan
# Processing record 379|quibdo
# Processing record 380|koath
# Processing record 381|vila velha
# Processing record 382|lasa
# Processing record 383|kismayo
# Processing record 384|panguipulli
# City not found. skipping.
# Processing record 385|barpeta
# Processing record 386|falesti
# Processing record 387|lazaro cardenas
# Processing record 388|wilmington
# Processing record 389|hovd
# Processing record 390|tomioka
# Processing record 391|fairbanks
# Processing record 392|parakou
# Processing record 393|harper
# Processing record 394|mandera
# Processing record 395|saint-georges
# Processing record 396|naron
# Processing record 397|los llanos de aridane
# Processing record 398|pirajui
# Processing record 399|kalaleh
# Processing record 400|camana
# Processing record 401|leningradskiy
# Processing record 402|cadiz
# Processing record 403|lanquin
# Processing record 404|andenes
# Processing record 405|grafton
# Processing record 406|pericos
# Processing record 407|bayonet point
# Processing record 408|tehachapi
# Processing record 409|quthing
# Processing record 410|coquimbo
# Processing record 411|atambua
# Processing record 412|jaciara
# Processing record 413|mastic beach
# Processing record 414|bethal
# Processing record 415|vilyuysk
# Processing record 416|pustoshka
# Processing record 417|carauari
# Processing record 418|iquitos
# City not found. skipping.
# Processing record 419|farah
# Processing record 420|macomb
# Processing record 421|berbera
# Processing record 422|mareeba
# Processing record 423|samana
# Processing record 424|yenagoa
# Processing record 425|mantua
# Processing record 426|aykhal
# Processing record 427|portland
# Processing record 428|humaita
# Processing record 429|waitati
# Processing record 430|warrnambool
# Processing record 431|hvolsvollur
# Processing record 432|ancud
# Processing record 433|clyde river
# Processing record 434|ruteng
# Processing record 435|palu
# Processing record 436|dingle
# Processing record 437|pochutla
# Processing record 438|saint-francois
# Processing record 439|cabedelo
# Processing record 440|tenenkou
# Processing record 441|nanortalik
# Processing record 442|san rafael
# Processing record 443|huilong
# Processing record 444|aleksandrov gay
# Processing record 445|bathsheba
# Processing record 446|nizhniy baskunchak
# Processing record 447|leua
# Processing record 448|pisco
# Processing record 449|matiguas
# Processing record 450|vao
# Processing record 451|ponta delgada
# Processing record 452|flinders
# Processing record 453|gunnedah
# Processing record 454|tambura
# Processing record 455|chingirlau
# Processing record 456|amarwara
# Processing record 457|taoudenni
# Processing record 458|la asuncion
# Processing record 459|ternate
# Processing record 460|hirara
# Processing record 461|nanding
# Processing record 462|sakakah
# Processing record 463|pangai
# Processing record 464|manokwari
# Processing record 465|solano
# Processing record 466|blythe
# Processing record 467|gubkinskiy
# Processing record 468|songkhla
# Processing record 469|buluang
# Processing record 470|hue
# Processing record 471|kaniama
# City not found. skipping.
# Processing record 472|sisimiut
# Processing record 473|san cristobal
# Processing record 474|seddon
# Processing record 475|albania
# Processing record 476|kungurtug
# Processing record 477|pareora
# Processing record 478|winchester
# City not found. skipping.
# Processing record 479|gdov
# Processing record 480|fort nelson
# Processing record 481|topchikha
# City not found. skipping.
# Processing record 482|ulladulla
# Processing record 483|itoman
# Processing record 484|shache
# Processing record 485|aberystwyth
# Processing record 486|veraval
# Processing record 487|duminichi
# Processing record 488|payson
# Processing record 489|hambantota
# City not found. skipping.
# Processing record 490|castanos
# Processing record 491|padang
# Processing record 492|bestobe
# Processing record 493|yulara
# Processing record 494|chokwe
# City not found. skipping.
# City not found. skipping.
# City not found. skipping.
# Processing record 495|mandalgovi
# Processing record 496|northam
# Processing record 497|kavieng
# Processing record 498|yerbogachen
# Processing record 499|severnyy-kospashskiy
# Processing record 500|dharmapuri
# Processing record 501|osorno
# City not found. skipping.
# Processing record 502|taltal
# Processing record 503|coihaique
# City not found. skipping.
# Processing record 504|tarauaca
# Processing record 505|shenjiamen
# Processing record 506|srednekolymsk
# Processing record 507|chengde
# City not found. skipping.
# Processing record 508|seredka
# Processing record 509|ngunguru
# Processing record 510|ust-barguzin
# Processing record 511|nome
# Processing record 512|krasnoselkup
# Processing record 513|yaan
# Processing record 514|viedma
# Processing record 515|wajir
# Processing record 516|aix-en-provence
# Processing record 517|general pico
# City not found. skipping.
# Processing record 518|opocno
# Processing record 519|rohru
# Processing record 520|korla
# Processing record 521|victor harbor
# Processing record 522|zhuhai
# Processing record 523|sharjah
# Processing record 524|sobolevo
# Processing record 525|hadishahr
# Processing record 526|kaeo
# Processing record 527|mlonggo
# Processing record 528|riyadh
# Processing record 529|ust-nera
# Processing record 530|sao gabriel da cachoeira
# Processing record 531|nalut
# Processing record 532|bilma
# Processing record 533|murshidabad
# Processing record 534|puri
# Processing record 535|balkhash
# Processing record 536|valleyview
# Processing record 537|abha
# Processing record 538|fairhope
# Processing record 539|molina
# Processing record 540|pingyin
# Processing record 541|saint anthony
# Processing record 542|pathein
# Processing record 543|wazirabad
# Processing record 544|hoquiam
# Processing record 545|omsukchan
# Processing record 546|jiupu
# City not found. skipping.
# Processing record 547|jacksonville
# Processing record 548|kumluca
# Processing record 549|torcy
# Processing record 550|tupaciguara
# Processing record 551|valparaiso
# Processing record 552|faya
# Processing record 553|umm lajj
# Processing record 554|la ciotat
# Processing record 555|olafsvik
# Processing record 556|kobryn
# Processing record 557|burgos
# Processing record 558|tooele
# Processing record 559|weinan
# Processing record 560|mount isa
# Processing record 561|la crosse
# Processing record 562|guane

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Creating city dataframe
city_df = pd.DataFrame({"City":city_name, 
                        "Cloudiness":cloudiness, 
                        "Country":country, 
                        "Date":date, 
                        "Humidity":humidity,
                        "Lat":lat,
                        "Lng":lng,
                        "Temperature":max_temp,
                        "Wind Speed":wind_speed
                                         })
city_df = city_df.rename_axis('City ID')

#Exporting data to csv
city_df.to_csv("../output_data/cities.csv")

#Displaying dataframe
city_df.head()
# Out:
#                City  Cloudiness Country        Date  Humidity      Lat  \
# City ID
# 0            Atuona          43      PF  1651163430        78  -9.8000
# 1         Joshīmath          84      IN  1651163431        69  30.5667
# 2        Lavrentiya          99      RU  1651163431        92  65.5833
# 3         Busselton          82      AU  1651163431        77 -33.6500
# 4           Erenhot         100      CN  1651163432        21  43.6475
#
#               Lng  Temperature  Wind Speed
# City ID
# 0       -139.0333        78.44       21.63
# 1         79.5667        60.73        7.27
# 2       -171.0000        26.17        9.08
# 3        115.3333        56.89        5.53
# 4        111.9767        52.30        6.89

# %%
city_df.count()
# Out:
# City           562
# Cloudiness     562
# Country        562
# Date           562
# Humidity       562
# Lat            562
# Lng            562
# Temperature    562
# Wind Speed     562
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
city_df=pd.read_csv("../output_data/cities.csv")

# %%
x_values = city_df["Lat"]
y_values = city_df["Temperature"]

plt.scatter(x_values,y_values)
plt.title('Temperatures at Latitude Positions')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.ylim(0, 100)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = city_df["Lat"]
y_values = city_df["Humidity"]

plt.scatter(x_values,y_values)
plt.title('Humidity at Latitude Positions')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(0, 105)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = city_df["Lat"]
y_values = city_df["Cloudiness"]

plt.scatter(x_values,y_values)
plt.title('Cloudiness at Latitude Positions')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.ylim(-5, 105)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = city_df["Lat"]
y_values = city_df["Wind Speed"]

plt.scatter(x_values,y_values)
plt.title('Wind Speeds at Latitude Positions')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylim(0, 40)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
mask = city_df['Lat'] > 0
northern_hemisphere = city_df[mask]
southern_hemisphere = city_df[~mask]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Temperature"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.title('Temperatures at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.ylim(-5, 100)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Temperature"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.title('Temperatures at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,80),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.ylim(40, 100)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.title('Humidity at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,80),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(0, 105)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.title('Humidity at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(0, 105)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.title('Cloudiness at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,60),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.ylim(-5, 105)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.title('Wind Speed at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylim(0, 40)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.title('Wind Speed at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylim(0, 35)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.show()
